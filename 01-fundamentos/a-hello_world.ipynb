# %% [markdown]
# # Fundamentos

# %% [markdown]
# ## Jupyter Notebook
#
# Vamos utilizar para realizar todas as praticas e testes. A ideia que por essa ferramentas iremos realizar todos os casos de testes.
# Em um novo projeto, utilizando o Vs Code, precisamos indicar o "kernel" que irá ser responsável por processar as requisições.
#
# - Selecionando Kernel:
#
# ...
#
# - Intalando bibliotecas

# %%
print("hello world")
# Out:
# hello world
